# %%
#My Own Word2Vec try
import numpy as np
import random

from FunctionAssign1_basic import softmax
from FunctionAssign1_basic import sigmoid, sigmoid_grad

def normalizeRows(x):
    """ Row normalization function
    Implement a function that normalizes each row of a matrix to have
    unit length.
    """
    x_square = x**2
    x_square_sum = np.sqrt(x_square.sum(axis=1)).reshape((-1,1))
    x /= x_square_sum
    return x


def softmaxCostAndGradient(predicted, target, outputVectors):
    V,d = outputVectors.shape
    print("V, %f d %f "%(V,d))
    
    #a kind of forward prog got the output
    output = softmax(np.dot(predicted,outputVectors.T))
    print("output after softmax ", output)
    #cross entropy cost
    cost = (-1) * np.log(output[target])
    
    # 3(a)
    reshapeOutput = output.reshape((-1,1))
    print("reshapeOutput ", reshapeOutput)
    
    
    
    
    
    
    return None

if __name__ == "__main__":
    sampleMatrix = np.random.randn(20,5)
    print("Original Sample Matrix ", sampleMatrix)
    print("Sample Matrix After normalize ", normalizeRows(sampleMatrix))
    
    tokens_dict = dict([("this",0), ("is",1), ("my",2),("nice",3),("schoolbag",4)])
    
    grad = np.zeros(sampleMatrix.shape)
    
    N = sampleMatrix.shape[0]
    N_half = int(N/2)
    inputVectors = sampleMatrix[:N_half,:]
    outputVectors = sampleMatrix[N_half:,:]
    print("inputVectors ", inputVectors)
    print("outputVectors ", outputVectors)
    
    tokens=["this","is", "my","nice","schoolbag"]
    #Just test one round
    centerword = tokens[random.randint(0,4)]
    context = [tokens[random.randint(0,4)] for i in range(2*3)]
    print("CenterWord ", centerword)
    print("context ", context)
    
    cost = 0.0
    #Delta V0
    gradIn = np.zeros(inputVectors.shape)
    #Delta Out
    gradOut = np.zeros(outputVectors.shape)
    
    inputIndex = tokens_dict[centerword]
    inputV0 = inputVectors[inputIndex]
    
    
    for contextWord in context:
        target = tokens_dict[contextWord]
        softmaxCostAndGradient(inputV0, target,outputVectors)
# Out:
# Original Sample Matrix  [[ -9.87952360e-01  -2.95453270e-02   5.47119384e-01  -1.21303391e+00
#    -1.76454176e-01]
#  [  7.44078117e-01  -4.26154207e-01   7.75917011e-02  -2.48750383e+00
#     2.54438397e-01]
#  [  1.03574615e+00  -6.58809162e-01   4.13382013e-03  -1.17200629e-01
#     9.92604637e-01]
#  [  1.02987494e-01  -6.21059353e-01   4.41104373e-01  -6.44647423e-01
#    -1.38009565e+00]
#  [  1.31003628e+00  -2.25874269e-01   9.68136815e-01   3.93364187e-01
#     5.30599756e-01]
#  [ -2.85132214e-01  -4.84293203e-01  -2.02836292e-01   1.11798244e+00
#     3.47251668e-01]
#  [  9.69342671e-01   6.13055871e-01  -5.70148014e-01   9.82315712e-01
#     1.72905165e-01]
#  [  1.58215188e+00   3.63053868e-01   1.62707125e+00   7.18814140e-01
# CenterWord  schoolbag
# context  ['nice', 'is', 'this', 'is', 'this', 'nice']
# V, 10.000000 d 5.000000
# output after softmax  [ 0.15099699  0.12213382  0.08194057  0.08803874  0.0798228   0.10588743
#   0.15474786  0.09328231  0.04709654  0.07605293]
# reshapeOutput  [[ 0.15099699]
#  [ 0.12213382]
#  [ 0.08194057]
#  [ 0.08803874]
#  [ 0.0798228 ]
#  [ 0.10588743]
#  [ 0.15474786]
#  [ 0.09328231]
#  [ 0.04709654]
#  [ 0.07605293]]
# V, 10.000000 d 5.000000
# output after softmax  [ 0.15099699  0.12213382  0.08194057  0.08803874  0.0798228   0.10588743
#   0.15474786  0.09328231  0.04709654  0.07605293]
# reshapeOutput  [[ 0.15099699]
#  [ 0.12213382]
#  [ 0.08194057]
#  [ 0.08803874]
#  [ 0.0798228 ]
#  [ 0.10588743]
#  [ 0.15474786]
#  [ 0.09328231]
#  [ 0.04709654]
#  [ 0.07605293]]
# V, 10.000000 d 5.000000
# output after softmax  [ 0.15099699  0.12213382  0.08194057  0.08803874  0.0798228   0.10588743
#   0.15474786  0.09328231  0.04709654  0.07605293]
# reshapeOutput  [[ 0.15099699]
#  [ 0.12213382]
#  [ 0.08194057]
#  [ 0.08803874]
#  [ 0.0798228 ]
#  [ 0.10588743]
#  [ 0.15474786]
#  [ 0.09328231]
#  [ 0.04709654]
#  [ 0.07605293]]
# V, 10.000000 d 5.000000
# output after softmax  [ 0.15099699  0.12213382  0.08194057  0.08803874  0.0798228   0.10588743
#   0.15474786  0.09328231  0.04709654  0.07605293]
# reshapeOutput  [[ 0.15099699]
#  [ 0.12213382]
#  [ 0.08194057]
#  [ 0.08803874]
#  [ 0.0798228 ]
#  [ 0.10588743]
#  [ 0.15474786]
#  [ 0.09328231]
#  [ 0.04709654]
#  [ 0.07605293]]
# V, 10.000000 d 5.000000
# output after softmax  [ 0.15099699  0.12213382  0.08194057  0.08803874  0.0798228   0.10588743
#   0.15474786  0.09328231  0.04709654  0.07605293]
# reshapeOutput  [[ 0.15099699]
#  [ 0.12213382]
#  [ 0.08194057]
#  [ 0.08803874]
#  [ 0.0798228 ]
#  [ 0.10588743]
#  [ 0.15474786]
#  [ 0.09328231]
#  [ 0.04709654]
#  [ 0.07605293]]
# V, 10.000000 d 5.000000
# output after softmax  [ 0.15099699  0.12213382  0.08194057  0.08803874  0.0798228   0.10588743
#   0.15474786  0.09328231  0.04709654  0.07605293]
# reshapeOutput  [[ 0.15099699]
#  [ 0.12213382]
#  [ 0.08194057]
#  [ 0.08803874]
#  [ 0.0798228 ]
#  [ 0.10588743]
#  [ 0.15474786]
#  [ 0.09328231]
#  [ 0.04709654]
#  [ 0.07605293]]
